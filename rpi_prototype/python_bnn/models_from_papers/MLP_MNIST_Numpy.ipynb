# %%
import tensorflow.keras.datasets.mnist as mnist
import numpy as np
import matplotlib.pyplot as plt
import time

import sys
import os
sys.path.insert(0, os.path.abspath("../"))

from core.label_utils import label_binerizer

# %% [markdown]
# ### Import and prepare dataset

# %%
BATCH_NORM_MOMENTUM=0.9
BATCH_SIZE = 100
LR_ADAM=1e-3 # from paper pg 18: https://openreview.net/pdf?id=pwwVuSICBgt
LR_SGD=1e-1 # from paper pg 18: https://openreview.net/pdf?id=pwwVuSICBgt
DTYPE = np.float32

# %%
(X_train, y_train), (X_test, y_test) = mnist.load_data()
X_train = np.expand_dims(X_train.astype(DTYPE), -1)/255
y_train = label_binerizer(y_train.astype(int), n_class=10)
X_test = np.expand_dims(X_test, -1).astype(DTYPE)/255
y_test = label_binerizer(y_test.astype(int), n_class=10)

idx_choice = list(range(len(X_test)))

print("Training samples: ", X_train.shape)
print("Testing samples: ", X_test.shape)
# Out:
# Training samples:  (60000, 28, 28, 1)
# Testing samples:  (10000, 28, 28, 1)

# %% [markdown]
# ### Numpy full model implementation

# %% [markdown]
# ### Binary model

# %%
#del sys.modules["core.binary_models.layers"]
from core.numpy_models.full_precision_models.layers import Flatten, Softmax
from core.losses import CrossEntropy
from core.optimizers import GradientDescent, Adam
from core.label_utils import label_binerizer

from core.numpy_models.binary_models.layers import BinaryDense, BinaryConv2D#, BatchNorm
from core.numpy_models.xnor_models.layers import  BatchNorm
from core.numpy_models.binary_models.activation_layers import BinaryActivation
from core.model import Sequential

# %%
### Single conv + flatten + dense layer


model_layers = [
    Flatten(), 
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(10, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    Softmax()
]

loss_op = CrossEntropy()
optimizer_op = GradientDescent(lr=LR_SGD)

LeNet5_numpy = Sequential(model_layers)
LeNet5_numpy.compile(loss_op, optimizer_op)


for epoch in range(100):
    loss_batch = np.array([])
    acc_batch = np.array([])
    start_time = time.time()
    for j in range(len(X_train)//BATCH_SIZE):
        print(f"Batch {j}", end="\r")
        X_batch = X_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        y_batch = y_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        LeNet5_numpy.fit_step(X_batch, y_batch, curr_step=epoch)
        loss_batch = np.append(loss_batch, LeNet5_numpy.loss)
        acc_batch = np.append(acc_batch, LeNet5_numpy.accuracy)
    end_time = time.time()
    rnd_idx = np.random.choice(idx_choice, size=5000, replace=False)
    LeNet5_numpy.validate_step(X=X_test[rnd_idx], y=y_test[rnd_idx], curr_step=epoch)
    print(f"Epoch {epoch}, training time = {end_time-start_time} s:") 
    print(f"Loss = {np.mean(loss_batch)}, Accuracy = {np.mean(acc_batch)}")
    print(f"Validation loss = {LeNet5_numpy.validation_loss}, Validation accuracy = {LeNet5_numpy.validation_accuracy}")
# Out:
# Epoch 0, training time = 20.13914918899536 s:
# Loss = 0.4307805379231771, Accuracy = 0.8940666666666668
# Validation loss = 0.29248046875, Validation accuracy = 0.9256
# Epoch 1, training time = 19.85128140449524 s:
# Loss = 0.28419336954752605, Accuracy = 0.9331999999999999
# Validation loss = 0.24609375, Validation accuracy = 0.9382
# Epoch 2, training time = 20.064897537231445 s:
# Loss = 0.24467595418294272, Accuracy = 0.9442833333333333
# Validation loss = 0.2261962890625, Validation accuracy = 0.9484
# Epoch 3, training time = 19.58268404006958 s:
# Loss = 0.2242730712890625, Accuracy = 0.9518833333333333
# Validation loss = 0.2103271484375, Validation accuracy = 0.95
# Epoch 4, training time = 19.684598207473755 s:
# Loss = 0.20936335245768228, Accuracy = 0.9558333333333333
# Validation loss = 0.2054443359375, Validation accuracy = 0.953
# Epoch 5, training time = 19.978805541992188 s:
# Loss = 0.19917872111002605, Accuracy = 0.9593
# Validation loss = 0.1968994140625, Validation accuracy = 0.9522
# Epoch 6, training time = 20.09193992614746 s:
# Loss = 0.19119094848632812, Accuracy = 0.9620000000000001
# Validation loss = 0.197265625, Validation accuracy = 0.9546
# Epoch 7, training time = 20.014062643051147 s:
# Loss = 0.18428258260091146, Accuracy = 0.9637
# Validation loss = 0.1859130859375, Validation accuracy = 0.956
# Epoch 8, training time = 19.945106744766235 s:
# Loss = 0.17978871663411458, Accuracy = 0.9653833333333334
# Validation loss = 0.1756591796875, Validation accuracy = 0.9584
# Epoch 9, training time = 19.806627988815308 s:
# Loss = 0.17454722086588542, Accuracy = 0.9666666666666667
# Validation loss = 0.188232421875, Validation accuracy = 0.955
# Epoch 10, training time = 19.81902265548706 s:
# Loss = 0.17063680013020832, Accuracy = 0.9681333333333333
# Validation loss = 0.17626953125, Validation accuracy = 0.9626
# Epoch 11, training time = 19.934641122817993 s:
# Loss = 0.16746683756510417, Accuracy = 0.9695
# Validation loss = 0.1761474609375, Validation accuracy = 0.96
# Epoch 12, training time = 19.56430983543396 s:
# Loss = 0.16389175415039062, Accuracy = 0.9696833333333332
# Validation loss = 0.1837158203125, Validation accuracy = 0.959
# Epoch 13, training time = 19.60817265510559 s:
# Loss = 0.16271011352539064, Accuracy = 0.9705666666666666
# Validation loss = 0.182373046875, Validation accuracy = 0.9562
# Epoch 14, training time = 19.241715669631958 s:
# Loss = 0.1604541015625, Accuracy = 0.9718999999999998
# Validation loss = 0.1763916015625, Validation accuracy = 0.9604
# Epoch 15, training time = 19.42061448097229 s:
# Loss = 0.15765167236328126, Accuracy = 0.9725499999999999
# Validation loss = 0.1773681640625, Validation accuracy = 0.9586
# Epoch 16, training time = 19.799426078796387 s:
# Loss = 0.15569137573242187, Accuracy = 0.9734999999999998
# Validation loss = 0.18701171875, Validation accuracy = 0.9576
# Epoch 17, training time = 19.54313039779663 s:
# Loss = 0.153184814453125, Accuracy = 0.97355
# Validation loss = 0.165283203125, Validation accuracy = 0.9614
# Epoch 18, training time = 19.561290502548218 s:
# Loss = 0.1512553914388021, Accuracy = 0.9751833333333334
# Validation loss = 0.175537109375, Validation accuracy = 0.9628
# Epoch 19, training time = 19.756667613983154 s:
# Loss = 0.15079142252604166, Accuracy = 0.9749166666666668
# Validation loss = 0.185546875, Validation accuracy = 0.956
# Epoch 20, training time = 19.591193914413452 s:
# Loss = 0.1490032958984375, Accuracy = 0.9751499999999999
# Validation loss = 0.160400390625, Validation accuracy = 0.966
# Epoch 21, training time = 20.053359270095825 s:
# Loss = 0.14839859008789064, Accuracy = 0.9757333333333335
# Validation loss = 0.1690673828125, Validation accuracy = 0.9616
# Epoch 22, training time = 19.70304274559021 s:
# Loss = 0.14650889078776042, Accuracy = 0.9761500000000001
# Validation loss = 0.164306640625, Validation accuracy = 0.964
# Epoch 23, training time = 19.999317407608032 s:
# Loss = 0.14646876017252605, Accuracy = 0.97635
# Validation loss = 0.17578125, Validation accuracy = 0.962
# Epoch 24, training time = 19.813007593154907 s:
# Loss = 0.14441925048828125, Accuracy = 0.9773166666666666
# Validation loss = 0.1695556640625, Validation accuracy = 0.9632
# Epoch 25, training time = 19.603237628936768 s:
# Loss = 0.14580235799153646, Accuracy = 0.9761000000000002
# Validation loss = 0.1668701171875, Validation accuracy = 0.9638
# Epoch 26, training time = 21.290250778198242 s:
# Loss = 0.14435948689778647, Accuracy = 0.9774833333333334
# Validation loss = 0.1602783203125, Validation accuracy = 0.9638
# Epoch 27, training time = 21.02183246612549 s:
# Loss = 0.14279871622721355, Accuracy = 0.9775
# Validation loss = 0.158203125, Validation accuracy = 0.9666
# Epoch 28, training time = 20.29206609725952 s:
# Loss = 0.14339772542317708, Accuracy = 0.9770333333333334
# Validation loss = 0.1826171875, Validation accuracy = 0.9592
# Epoch 29, training time = 20.006282329559326 s:
# Loss = 0.1426043192545573, Accuracy = 0.9771333333333333
# Validation loss = 0.17333984375, Validation accuracy = 0.9638
# Epoch 30, training time = 19.64130997657776 s:
# Loss = 0.13906717936197915, Accuracy = 0.9788333333333332
# Validation loss = 0.1597900390625, Validation accuracy = 0.9662
# Epoch 31, training time = 20.216984033584595 s:
# Loss = 0.14043909708658855, Accuracy = 0.9785333333333331
# Validation loss = 0.165771484375, Validation accuracy = 0.964
# Epoch 32, training time = 20.593173503875732 s:
# Loss = 0.13952667236328126, Accuracy = 0.9783499999999999
# Validation loss = 0.172607421875, Validation accuracy = 0.9648
# Epoch 33, training time = 19.91792631149292 s:
# Loss = 0.13812769571940103, Accuracy = 0.9791000000000001
# Validation loss = 0.16064453125, Validation accuracy = 0.9682
# Epoch 34, training time = 20.047596216201782 s:
# Loss = 0.13861913045247395, Accuracy = 0.9789833333333333
# Validation loss = 0.1763916015625, Validation accuracy = 0.9624
# Epoch 35, training time = 19.93624520301819 s:
# Loss = 0.13864217122395833, Accuracy = 0.9787833333333333
# Validation loss = 0.179443359375, Validation accuracy = 0.9612
# Epoch 36, training time = 19.85392689704895 s:
# Loss = 0.13701395670572916, Accuracy = 0.9797499999999999
# Validation loss = 0.17333984375, Validation accuracy = 0.9622
# Epoch 37, training time = 19.81464958190918 s:
# Loss = 0.13504989624023436, Accuracy = 0.9798999999999999
# Validation loss = 0.1724853515625, Validation accuracy = 0.9646
# Epoch 38, training time = 19.878380060195923 s:
# Loss = 0.13531199137369793, Accuracy = 0.9798500000000001
# Validation loss = 0.17529296875, Validation accuracy = 0.9614
# Epoch 39, training time = 20.02973747253418 s:
# Loss = 0.137493896484375, Accuracy = 0.9795833333333334
# Validation loss = 0.163818359375, Validation accuracy = 0.9654
# Epoch 40, training time = 20.08197522163391 s:
# Loss = 0.13547475179036458, Accuracy = 0.9803166666666667
# Validation loss = 0.1773681640625, Validation accuracy = 0.9598
# Epoch 41, training time = 19.681654691696167 s:
# Loss = 0.13541524251302084, Accuracy = 0.9802166666666666
# Validation loss = 0.15234375, Validation accuracy = 0.9662
# Epoch 42, training time = 20.189021348953247 s:
# Loss = 0.13337834676106772, Accuracy = 0.9810666666666669
# Validation loss = 0.1802978515625, Validation accuracy = 0.9608
# Epoch 43, training time = 19.976439714431763 s:
# Loss = 0.1333575948079427, Accuracy = 0.9811000000000001
# Validation loss = 0.17138671875, Validation accuracy = 0.9632
# Epoch 44, training time = 19.71004581451416 s:
# Loss = 0.13311996459960937, Accuracy = 0.9807500000000001
# Validation loss = 0.168212890625, Validation accuracy = 0.965
# Epoch 45, training time = 20.019675254821777 s:
# Loss = 0.1330065409342448, Accuracy = 0.9814166666666665
# Validation loss = 0.1671142578125, Validation accuracy = 0.964
# Epoch 46, training time = 19.749390602111816 s:
# Loss = 0.13302286783854167, Accuracy = 0.9804499999999999
# Validation loss = 0.17236328125, Validation accuracy = 0.9614
# Epoch 47, training time = 19.9611074924469 s:
# Loss = 0.13267720540364583, Accuracy = 0.98065
# Validation loss = 0.171875, Validation accuracy = 0.9642
# Epoch 48, training time = 20.149705410003662 s:
# Loss = 0.13342076619466145, Accuracy = 0.9805833333333331
# Validation loss = 0.1473388671875, Validation accuracy = 0.9692
# Epoch 49, training time = 19.918461084365845 s:
# Loss = 0.13153661092122396, Accuracy = 0.98125
# Validation loss = 0.1607666015625, Validation accuracy = 0.966
# Epoch 50, training time = 20.02234411239624 s:
# Loss = 0.13238006591796875, Accuracy = 0.9808166666666667
# Validation loss = 0.1676025390625, Validation accuracy = 0.965
# Epoch 51, training time = 20.85740327835083 s:
# Loss = 0.13222081502278646, Accuracy = 0.9811166666666666
# Validation loss = 0.15625, Validation accuracy = 0.967
# Epoch 52, training time = 20.84971046447754 s:
# Loss = 0.13081044514973958, Accuracy = 0.9815000000000002
# Validation loss = 0.1702880859375, Validation accuracy = 0.9634
# Epoch 53, training time = 20.35329246520996 s:
# Loss = 0.13233322143554688, Accuracy = 0.9807833333333333
# Validation loss = 0.1690673828125, Validation accuracy = 0.963
# Epoch 54, training time = 20.011410236358643 s:
# Loss = 0.1309161376953125, Accuracy = 0.9811333333333334
# Validation loss = 0.1707763671875, Validation accuracy = 0.9642
# Epoch 55, training time = 19.95920729637146 s:
# Loss = 0.13011144002278646, Accuracy = 0.9816166666666667
# Validation loss = 0.158203125, Validation accuracy = 0.9658
# Epoch 56, training time = 19.756612300872803 s:
# Loss = 0.13067423502604167, Accuracy = 0.9813166666666668
# Validation loss = 0.1651611328125, Validation accuracy = 0.9642
# Epoch 57, training time = 19.60665535926819 s:
# Loss = 0.12946680704752603, Accuracy = 0.9820000000000001
# Validation loss = 0.1572265625, Validation accuracy = 0.9664
# Epoch 58, training time = 20.2156400680542 s:
# Loss = 0.1298131815592448, Accuracy = 0.98125
# Validation loss = 0.166015625, Validation accuracy = 0.9636
# Epoch 59, training time = 19.884188890457153 s:
# Loss = 0.1299212646484375, Accuracy = 0.9821999999999999
# Validation loss = 0.158447265625, Validation accuracy = 0.969
# Epoch 60, training time = 19.812058448791504 s:
# Loss = 0.13003443400065104, Accuracy = 0.9819833333333334
# Validation loss = 0.16162109375, Validation accuracy = 0.9652
# Epoch 61, training time = 19.663086891174316 s:
# Loss = 0.12905899047851563, Accuracy = 0.9819166666666668
# Validation loss = 0.15673828125, Validation accuracy = 0.966
# Epoch 62, training time = 19.608709573745728 s:
# Loss = 0.12933390299479167, Accuracy = 0.9815833333333333
# Validation loss = 0.1595458984375, Validation accuracy = 0.9642
# Epoch 63, training time = 19.649285316467285 s:
# Loss = 0.12831502278645834, Accuracy = 0.9823
# Validation loss = 0.1710205078125, Validation accuracy = 0.9624
# Epoch 64, training time = 20.23555588722229 s:
# Loss = 0.12903223673502603, Accuracy = 0.98185
# Validation loss = 0.162109375, Validation accuracy = 0.9664
# Epoch 65, training time = 19.55579948425293 s:
# Loss = 0.12842244466145833, Accuracy = 0.9821333333333333
# Validation loss = 0.154296875, Validation accuracy = 0.966
# Epoch 66, training time = 19.652369499206543 s:
# Loss = 0.12654637654622397, Accuracy = 0.9829833333333334
# Validation loss = 0.1611328125, Validation accuracy = 0.9658
# Epoch 67, training time = 19.667068243026733 s:
# Loss = 0.12508494059244793, Accuracy = 0.9834999999999998
# Validation loss = 0.15478515625, Validation accuracy = 0.9674
# Epoch 68, training time = 19.834660291671753 s:
# Loss = 0.127552490234375, Accuracy = 0.9823500000000002
# Validation loss = 0.16162109375, Validation accuracy = 0.9644
# Epoch 69, training time = 19.854691982269287 s:
# Loss = 0.1271404520670573, Accuracy = 0.9822166666666667
# Validation loss = 0.1650390625, Validation accuracy = 0.9638
# Epoch 70, training time = 19.38157629966736 s:
# Loss = 0.12775746663411458, Accuracy = 0.9821
# Validation loss = 0.150390625, Validation accuracy = 0.9688
# Epoch 71, training time = 20.09500813484192 s:
# Loss = 0.12499562581380208, Accuracy = 0.9833000000000001
# Validation loss = 0.164306640625, Validation accuracy = 0.9658
# Epoch 72, training time = 19.758614778518677 s:
# Loss = 0.12585810343424478, Accuracy = 0.9831833333333335
# Validation loss = 0.1824951171875, Validation accuracy = 0.9592
# Epoch 73, training time = 19.80036211013794 s:
# Loss = 0.12591379801432293, Accuracy = 0.9827500000000001
# Validation loss = 0.1673583984375, Validation accuracy = 0.962
# Epoch 74, training time = 20.07380962371826 s:
# Loss = 0.12532811482747397, Accuracy = 0.9829833333333333
# Validation loss = 0.15673828125, Validation accuracy = 0.9666
# Epoch 75, training time = 20.02536153793335 s:
# Loss = 0.12486551920572916, Accuracy = 0.98355
# Validation loss = 0.1585693359375, Validation accuracy = 0.9672
# Epoch 76, training time = 19.905349493026733 s:
# Loss = 0.1244959004720052, Accuracy = 0.9833333333333333
# Validation loss = 0.1605224609375, Validation accuracy = 0.967
# Epoch 77, training time = 23.081382989883423 s:
# Loss = 0.1259215799967448, Accuracy = 0.9835
# Validation loss = 0.1519775390625, Validation accuracy = 0.968
# Epoch 78, training time = 38.05372905731201 s:
# Loss = 0.12456471761067708, Accuracy = 0.9834666666666666
# Validation loss = 0.172607421875, Validation accuracy = 0.9636
# Epoch 79, training time = 39.85106682777405 s:
# Loss = 0.1258355712890625, Accuracy = 0.9833999999999999
# Validation loss = 0.174072265625, Validation accuracy = 0.961
# Epoch 80, training time = 38.230966567993164 s:
# Loss = 0.12567179361979167, Accuracy = 0.9832333333333334
# Validation loss = 0.1629638671875, Validation accuracy = 0.9636
# Epoch 81, training time = 38.18634533882141 s:
# Loss = 0.12533777872721355, Accuracy = 0.9826833333333336
# Validation loss = 0.181396484375, Validation accuracy = 0.9606
# Epoch 82, training time = 37.15532732009888 s:
# Loss = 0.12613204956054688, Accuracy = 0.9831666666666669
# Validation loss = 0.170654296875, Validation accuracy = 0.964
# Epoch 83, training time = 30.341763257980347 s:
# Loss = 0.12368047078450521, Accuracy = 0.9835333333333334
# Validation loss = 0.172607421875, Validation accuracy = 0.9622
# Epoch 84, training time = 31.63943862915039 s:
# Loss = 0.12370702107747396, Accuracy = 0.9837500000000002
# Validation loss = 0.1644287109375, Validation accuracy = 0.9656
# Epoch 85, training time = 33.68606448173523 s:
# Loss = 0.12463526407877604, Accuracy = 0.9836166666666668
# Validation loss = 0.1690673828125, Validation accuracy = 0.966
# Epoch 86, training time = 32.82179641723633 s:
# Loss = 0.12347376505533854, Accuracy = 0.9840500000000001
# Validation loss = 0.16796875, Validation accuracy = 0.9636
# Epoch 87, training time = 30.785044193267822 s:
# Loss = 0.12452596028645833, Accuracy = 0.98355
# Validation loss = 0.1708984375, Validation accuracy = 0.9626
# Epoch 88, training time = 30.55786681175232 s:
# Loss = 0.12400914510091146, Accuracy = 0.9842166666666666
# Validation loss = 0.1630859375, Validation accuracy = 0.965
# Epoch 89, training time = 30.847628355026245 s:
# Loss = 0.12385086059570312, Accuracy = 0.9839500000000002
# Validation loss = 0.1612548828125, Validation accuracy = 0.9658
# Epoch 90, training time = 33.32434129714966 s:
# Loss = 0.12447830200195313, Accuracy = 0.9835
# Validation loss = 0.1778564453125, Validation accuracy = 0.9612
# Epoch 91, training time = 31.049066305160522 s:
# Loss = 0.12610122680664063, Accuracy = 0.9833333333333333
# Validation loss = 0.171142578125, Validation accuracy = 0.9628
# Epoch 92, training time = 30.585529804229736 s:
# Loss = 0.12517684936523438, Accuracy = 0.9834333333333333
# Validation loss = 0.1632080078125, Validation accuracy = 0.9632
# Epoch 93, training time = 30.617874145507812 s:
# Loss = 0.12394414265950521, Accuracy = 0.9836500000000001
# Validation loss = 0.1624755859375, Validation accuracy = 0.9648
# Epoch 94, training time = 28.336674213409424 s:
# Loss = 0.12408803304036459, Accuracy = 0.98335
# Validation loss = 0.1787109375, Validation accuracy = 0.9616
# Epoch 95, training time = 28.295743227005005 s:
# Loss = 0.12320897420247395, Accuracy = 0.9834499999999999
# Validation loss = 0.1561279296875, Validation accuracy = 0.9672
# Epoch 96, training time = 31.030916690826416 s:
# Loss = 0.12134562174479167, Accuracy = 0.9850333333333333
# Validation loss = 0.16455078125, Validation accuracy = 0.9634
# Epoch 97, training time = 29.26274299621582 s:
# Loss = 0.12279546101888021, Accuracy = 0.9839333333333333
# Validation loss = 0.1739501953125, Validation accuracy = 0.9608
# Epoch 98, training time = 30.457762241363525 s:
# Loss = 0.12211405436197917, Accuracy = 0.9843333333333334
# Validation loss = 0.16796875, Validation accuracy = 0.9634
# Epoch 99, training time = 30.905901193618774 s:
# Loss = 0.1226654052734375, Accuracy = 0.9841333333333334
# Validation loss = 0.1593017578125, Validation accuracy = 0.9652

# %%
### Single conv + flatten + dense layer


model_layers = [
    Flatten(), 
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    BinaryDense(10, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    Softmax()
]

loss_op = CrossEntropy()
optimizer_op = Adam(lr=LR_ADAM)

LeNet5_numpy = Sequential(model_layers)
LeNet5_numpy.compile(loss_op, optimizer_op)

for epoch in range(100):
    loss_batch = np.array([])
    acc_batch = np.array([])
    start_time = time.time()
    for j in range(len(X_train)//BATCH_SIZE):
        print(f"Batch {j}", end="\r")
        X_batch = X_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        y_batch = y_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        LeNet5_numpy.fit_step(X_batch, y_batch, curr_step=epoch)
        loss_batch = np.append(loss_batch, LeNet5_numpy.loss)
        acc_batch = np.append(acc_batch, LeNet5_numpy.accuracy)
    end_time = time.time()
    rnd_idx = np.random.choice(idx_choice, size=5000, replace=False)
    LeNet5_numpy.validate_step(X=X_test[rnd_idx], y=y_test[rnd_idx], curr_step=epoch)
    print(f"Epoch {epoch}, training time = {end_time-start_time} s:") 
    print(f"Loss = {np.mean(loss_batch)}, Accuracy = {np.mean(acc_batch)}")
    print(f"Validation loss = {LeNet5_numpy.validation_loss}, Validation accuracy = {LeNet5_numpy.validation_accuracy}")
# Out:
# Epoch 0, training time = 33.270968437194824 s:
# Loss = 0.4378831990559896, Accuracy = 0.8915666666666667
# Validation loss = 0.2734375, Validation accuracy = 0.93
# Epoch 1, training time = 33.25434637069702 s:
# Loss = 0.28442525227864585, Accuracy = 0.9329999999999999
# Validation loss = 0.2393798828125, Validation accuracy = 0.9426
# Epoch 2, training time = 34.39118027687073 s:
# Loss = 0.24460047403971355, Accuracy = 0.9451499999999998
# Validation loss = 0.2178955078125, Validation accuracy = 0.951
# Epoch 3, training time = 36.24670648574829 s:
# Loss = 0.2259118143717448, Accuracy = 0.9505166666666666
# Validation loss = 0.1971435546875, Validation accuracy = 0.954
# Epoch 4, training time = 39.48231267929077 s:
# Loss = 0.21488505045572917, Accuracy = 0.9543166666666667
# Validation loss = 0.1988525390625, Validation accuracy = 0.9546
# Epoch 5, training time = 40.50728940963745 s:
# Loss = 0.2037714131673177, Accuracy = 0.9572333333333332
# Validation loss = 0.1912841796875, Validation accuracy = 0.9546
# Epoch 6, training time = 40.47765803337097 s:
# Loss = 0.19524464925130208, Accuracy = 0.9602666666666668
# Validation loss = 0.1966552734375, Validation accuracy = 0.9534
# Epoch 7, training time = 41.09122109413147 s:
# Loss = 0.19086939493815105, Accuracy = 0.9615666666666666
# Validation loss = 0.189453125, Validation accuracy = 0.955
# Epoch 8, training time = 41.11119532585144 s:
# Loss = 0.18641632080078124, Accuracy = 0.9630000000000001
# Validation loss = 0.180419921875, Validation accuracy = 0.9582
# Epoch 9, training time = 41.184550523757935 s:
# Loss = 0.18321065266927083, Accuracy = 0.9633333333333334
# Validation loss = 0.185302734375, Validation accuracy = 0.9574
# Epoch 10, training time = 35.414719104766846 s:
# Loss = 0.17842610677083334, Accuracy = 0.9656500000000001
# Validation loss = 0.179443359375, Validation accuracy = 0.9592
# Epoch 11, training time = 34.07201838493347 s:
# Loss = 0.17556447347005208, Accuracy = 0.9666
# Validation loss = 0.1732177734375, Validation accuracy = 0.9608
# Epoch 12, training time = 33.088961362838745 s:
# Loss = 0.17325663248697917, Accuracy = 0.96695
# Validation loss = 0.1790771484375, Validation accuracy = 0.9574
# Epoch 13, training time = 33.860292196273804 s:
# Loss = 0.1691820780436198, Accuracy = 0.96845
# Validation loss = 0.1795654296875, Validation accuracy = 0.9576
# Epoch 14, training time = 32.75542640686035 s:
# Loss = 0.1673193359375, Accuracy = 0.9686833333333333
# Validation loss = 0.1636962890625, Validation accuracy = 0.9626
# Epoch 15, training time = 33.30629515647888 s:
# Loss = 0.16632715861002603, Accuracy = 0.9691666666666666
# Validation loss = 0.1766357421875, Validation accuracy = 0.9594
# Epoch 16, training time = 32.44501352310181 s:
# Loss = 0.1625391642252604, Accuracy = 0.9704166666666667
# Validation loss = 0.1796875, Validation accuracy = 0.9582
# Epoch 17, training time = 32.062177658081055 s:
# Loss = 0.16194361368815105, Accuracy = 0.9707333333333332
# Validation loss = 0.16650390625, Validation accuracy = 0.9624
# Epoch 18, training time = 33.09763216972351 s:
# Loss = 0.16020696004231771, Accuracy = 0.9710500000000002
# Validation loss = 0.1756591796875, Validation accuracy = 0.9592
# Epoch 19, training time = 32.493953227996826 s:
# Loss = 0.1588983662923177, Accuracy = 0.9722500000000001
# Validation loss = 0.1622314453125, Validation accuracy = 0.964
# Epoch 20, training time = 32.492135763168335 s:
# Loss = 0.15718607584635416, Accuracy = 0.9723833333333335
# Validation loss = 0.1650390625, Validation accuracy = 0.9616
# Epoch 21, training time = 32.85028553009033 s:
# Loss = 0.15793075561523437, Accuracy = 0.97215
# Validation loss = 0.1741943359375, Validation accuracy = 0.9584
# Epoch 22, training time = 32.71306896209717 s:
# Loss = 0.15638956705729168, Accuracy = 0.9725
# Validation loss = 0.1680908203125, Validation accuracy = 0.9612
# Epoch 23, training time = 33.808852195739746 s:
# Loss = 0.1542485555013021, Accuracy = 0.9736000000000001
# Validation loss = 0.1732177734375, Validation accuracy = 0.9602
# Epoch 24, training time = 34.66848540306091 s:
# Loss = 0.15239247639973957, Accuracy = 0.9739166666666665
# Validation loss = 0.1834716796875, Validation accuracy = 0.9576
# Epoch 25, training time = 32.39513325691223 s:
# Loss = 0.15255228678385416, Accuracy = 0.9737833333333333
# Validation loss = 0.17333984375, Validation accuracy = 0.9596
# Epoch 26, training time = 33.38585019111633 s:
# Loss = 0.15130996704101562, Accuracy = 0.9744000000000002
# Validation loss = 0.1630859375, Validation accuracy = 0.9658
# Epoch 27, training time = 33.8207733631134 s:
# Loss = 0.15020278930664063, Accuracy = 0.9750999999999999
# Validation loss = 0.158447265625, Validation accuracy = 0.965
# Epoch 28, training time = 32.29989671707153 s:
# Loss = 0.14876001993815105, Accuracy = 0.9759833333333334
# Validation loss = 0.171142578125, Validation accuracy = 0.9598
# Epoch 29, training time = 32.788793087005615 s:
# Loss = 0.14853866577148436, Accuracy = 0.9753166666666667
# Validation loss = 0.1617431640625, Validation accuracy = 0.9648
# Epoch 30, training time = 32.62879395484924 s:
# Loss = 0.14651804606119792, Accuracy = 0.9765000000000001
# Validation loss = 0.16357421875, Validation accuracy = 0.9656
# Epoch 31, training time = 33.34965801239014 s:
# Loss = 0.14576807657877605, Accuracy = 0.9764166666666667
# Validation loss = 0.17138671875, Validation accuracy = 0.9632
# Epoch 32, training time = 33.368988037109375 s:
# Loss = 0.14660868326822918, Accuracy = 0.9763833333333332
# Validation loss = 0.155517578125, Validation accuracy = 0.9676
# Epoch 33, training time = 33.96479392051697 s:
# Loss = 0.14656992594401042, Accuracy = 0.9761333333333334
# Validation loss = 0.1624755859375, Validation accuracy = 0.9648
# Epoch 34, training time = 33.00851774215698 s:
# Loss = 0.14553858439127604, Accuracy = 0.9768333333333332
# Validation loss = 0.1683349609375, Validation accuracy = 0.9628
# Epoch 35, training time = 33.77902126312256 s:
# Loss = 0.1458655293782552, Accuracy = 0.9769333333333334
# Validation loss = 0.1705322265625, Validation accuracy = 0.9622
# Epoch 36, training time = 35.75204396247864 s:
# Loss = 0.1440844217936198, Accuracy = 0.9776166666666668
# Validation loss = 0.1669921875, Validation accuracy = 0.9628
# Epoch 37, training time = 35.10372734069824 s:
# Loss = 0.14376012166341146, Accuracy = 0.9772000000000001
# Validation loss = 0.17041015625, Validation accuracy = 0.9622
# Epoch 38, training time = 35.42672848701477 s:
# Loss = 0.1427495320638021, Accuracy = 0.9774666666666667
# Validation loss = 0.1646728515625, Validation accuracy = 0.9646
# Epoch 39, training time = 34.64238929748535 s:
# Loss = 0.14228225708007813, Accuracy = 0.9775333333333333
# Validation loss = 0.1676025390625, Validation accuracy = 0.9638
# Epoch 40, training time = 34.22932553291321 s:
# Loss = 0.14029139200846355, Accuracy = 0.9786000000000001
# Validation loss = 0.1612548828125, Validation accuracy = 0.963
# Epoch 41, training time = 35.1837682723999 s:
# Loss = 0.14256078084309895, Accuracy = 0.97745
# Validation loss = 0.1695556640625, Validation accuracy = 0.96
# Epoch 42, training time = 35.418691873550415 s:
# Loss = 0.1422956339518229, Accuracy = 0.9779666666666667
# Validation loss = 0.1710205078125, Validation accuracy = 0.9592
# Epoch 43, training time = 35.96396827697754 s:
# Loss = 0.14026240030924478, Accuracy = 0.9788
# Validation loss = 0.1846923828125, Validation accuracy = 0.9576
# Epoch 44, training time = 34.60733962059021 s:
# Loss = 0.1401947530110677, Accuracy = 0.97875
# Validation loss = 0.1614990234375, Validation accuracy = 0.9646
# Epoch 45, training time = 35.039721965789795 s:
# Loss = 0.14072962443033854, Accuracy = 0.9783499999999999
# Validation loss = 0.156005859375, Validation accuracy = 0.964
# Epoch 46, training time = 34.751277923583984 s:
# Loss = 0.1399315897623698, Accuracy = 0.9779833333333333
# Validation loss = 0.1668701171875, Validation accuracy = 0.9622
# Epoch 47, training time = 35.02874755859375 s:
# Loss = 0.13922078450520833, Accuracy = 0.9787333333333333
# Validation loss = 0.1776123046875, Validation accuracy = 0.9576
# Epoch 48, training time = 34.69197678565979 s:
# Loss = 0.13887858072916667, Accuracy = 0.9787333333333333
# Validation loss = 0.1575927734375, Validation accuracy = 0.9642
# Epoch 49, training time = 33.49539136886597 s:
# Loss = 0.13790974934895833, Accuracy = 0.9793833333333333
# Validation loss = 0.1656494140625, Validation accuracy = 0.9626
# Epoch 50, training time = 33.291762351989746 s:
# Loss = 0.13910018920898437, Accuracy = 0.9787333333333333
# Validation loss = 0.1610107421875, Validation accuracy = 0.965
# Epoch 51, training time = 33.449650287628174 s:
# Loss = 0.1365460713704427, Accuracy = 0.9799166666666668
# Validation loss = 0.1595458984375, Validation accuracy = 0.9632
# Epoch 52, training time = 34.71595072746277 s:
# Loss = 0.13788828531901043, Accuracy = 0.9794500000000002
# Validation loss = 0.1607666015625, Validation accuracy = 0.9638
# Epoch 53, training time = 40.01061677932739 s:
# Loss = 0.13796579996744793, Accuracy = 0.9796
# Validation loss = 0.1734619140625, Validation accuracy = 0.9612
# Epoch 54, training time = 40.90952658653259 s:
# Loss = 0.1371533711751302, Accuracy = 0.9800166666666666
# Validation loss = 0.17578125, Validation accuracy = 0.9612
# Epoch 55, training time = 41.22816801071167 s:
# Loss = 0.13724756876627603, Accuracy = 0.9798833333333332
# Validation loss = 0.16015625, Validation accuracy = 0.9646
# Epoch 56, training time = 41.10079550743103 s:
# Loss = 0.13721934000651043, Accuracy = 0.9792333333333335
# Validation loss = 0.159912109375, Validation accuracy = 0.965
# Epoch 57, training time = 41.40786385536194 s:
# Loss = 0.134346923828125, Accuracy = 0.9805833333333331
# Validation loss = 0.1610107421875, Validation accuracy = 0.9644
# Epoch 58, training time = 41.00677418708801 s:
# Loss = 0.13675196329752604, Accuracy = 0.9796333333333332
# Validation loss = 0.167236328125, Validation accuracy = 0.9608
# Epoch 59, training time = 40.72170305252075 s:
# Loss = 0.13582300821940105, Accuracy = 0.9800666666666666
# Validation loss = 0.170654296875, Validation accuracy = 0.9608
# Epoch 60, training time = 41.079363107681274 s:
# Loss = 0.1353657023111979, Accuracy = 0.9797166666666666
# Validation loss = 0.155517578125, Validation accuracy = 0.967
# Epoch 61, training time = 35.44098401069641 s:
# Loss = 0.13332132975260416, Accuracy = 0.9812833333333333
# Validation loss = 0.16748046875, Validation accuracy = 0.9614
# Epoch 62, training time = 34.338733196258545 s:
# Loss = 0.13580846150716147, Accuracy = 0.9800500000000002
# Validation loss = 0.1527099609375, Validation accuracy = 0.9694
# Epoch 63, training time = 34.557080030441284 s:
# Loss = 0.13712982177734376, Accuracy = 0.9793666666666667
# Validation loss = 0.1640625, Validation accuracy = 0.9646
# Epoch 64, training time = 34.60567760467529 s:
# Loss = 0.13275609334309896, Accuracy = 0.9809
# Validation loss = 0.1673583984375, Validation accuracy = 0.9642
# Epoch 65, training time = 34.75304961204529 s:
# Loss = 0.13485382080078126, Accuracy = 0.9801499999999999
# Validation loss = 0.159423828125, Validation accuracy = 0.9642
# Epoch 66, training time = 34.336261510849 s:
# Loss = 0.13497940063476563, Accuracy = 0.9804833333333333
# Validation loss = 0.1712646484375, Validation accuracy = 0.9614
# Epoch 67, training time = 34.325084924697876 s:
# Loss = 0.13387542724609375, Accuracy = 0.9806000000000002
# Validation loss = 0.160888671875, Validation accuracy = 0.9638
# Epoch 68, training time = 34.67980146408081 s:
# Loss = 0.13470484415690104, Accuracy = 0.9802833333333335
# Validation loss = 0.156982421875, Validation accuracy = 0.9672
# Epoch 69, training time = 33.18865728378296 s:
# Loss = 0.13500279744466145, Accuracy = 0.9795666666666667
# Validation loss = 0.16455078125, Validation accuracy = 0.9642
# Epoch 70, training time = 33.859694957733154 s:
# Loss = 0.13543924967447918, Accuracy = 0.9798500000000001
# Validation loss = 0.167236328125, Validation accuracy = 0.965
# Epoch 71, training time = 34.12207627296448 s:
# Loss = 0.13381128946940105, Accuracy = 0.9807333333333335
# Validation loss = 0.16796875, Validation accuracy = 0.9626
# Epoch 72, training time = 33.601988792419434 s:
# Loss = 0.13197052001953125, Accuracy = 0.9812333333333334
# Validation loss = 0.1685791015625, Validation accuracy = 0.9632
# Epoch 73, training time = 33.66337990760803 s:
# Loss = 0.13244054158528645, Accuracy = 0.98105
# Validation loss = 0.1651611328125, Validation accuracy = 0.9632
# Epoch 74, training time = 34.376025676727295 s:
# Loss = 0.13214482625325522, Accuracy = 0.9815333333333335
# Validation loss = 0.15234375, Validation accuracy = 0.967
# Epoch 75, training time = 34.0849244594574 s:
# Loss = 0.13378957112630208, Accuracy = 0.9804
# Validation loss = 0.1783447265625, Validation accuracy = 0.9594
# Epoch 76, training time = 34.30432844161987 s:
# Loss = 0.13311325073242186, Accuracy = 0.9806833333333332
# Validation loss = 0.180419921875, Validation accuracy = 0.9588
# Epoch 77, training time = 34.09570574760437 s:
# Loss = 0.13212366739908854, Accuracy = 0.9818166666666667
# Validation loss = 0.1668701171875, Validation accuracy = 0.9626
# Epoch 78, training time = 34.619147539138794 s:
# Loss = 0.13273646036783854, Accuracy = 0.9809833333333334
# Validation loss = 0.159912109375, Validation accuracy = 0.9652
# Epoch 79, training time = 34.27789831161499 s:
# Loss = 0.13165262858072915, Accuracy = 0.9813
# Validation loss = 0.1666259765625, Validation accuracy = 0.9604
# Epoch 80, training time = 33.958510398864746 s:
# Loss = 0.13367650349934895, Accuracy = 0.9803166666666667
# Validation loss = 0.1602783203125, Validation accuracy = 0.9654
# Epoch 81, training time = 33.799293994903564 s:
# Loss = 0.1318005879720052, Accuracy = 0.9821
# Validation loss = 0.16064453125, Validation accuracy = 0.9642
# Epoch 82, training time = 34.06959271430969 s:
# Loss = 0.13290369669596355, Accuracy = 0.9812666666666666
# Validation loss = 0.1650390625, Validation accuracy = 0.9634
# Epoch 83, training time = 33.81245994567871 s:
# Loss = 0.1313555908203125, Accuracy = 0.9816333333333334
# Validation loss = 0.1585693359375, Validation accuracy = 0.967
# Epoch 84, training time = 33.88780641555786 s:
# Loss = 0.12966354370117186, Accuracy = 0.9817999999999999
# Validation loss = 0.1602783203125, Validation accuracy = 0.9652
# Epoch 85, training time = 33.94968056678772 s:
# Loss = 0.13087880452473957, Accuracy = 0.9818666666666669
# Validation loss = 0.1544189453125, Validation accuracy = 0.9672
# Epoch 86, training time = 33.98946690559387 s:
# Loss = 0.13110819498697918, Accuracy = 0.98125
# Validation loss = 0.155029296875, Validation accuracy = 0.9672
# Epoch 87, training time = 34.15581655502319 s:
# Loss = 0.13066446940104168, Accuracy = 0.98165
# Validation loss = 0.168701171875, Validation accuracy = 0.9632
# Epoch 88, training time = 34.496666431427 s:
# Loss = 0.13068822224934895, Accuracy = 0.9822000000000001
# Validation loss = 0.16552734375, Validation accuracy = 0.9632
# Epoch 89, training time = 35.908090353012085 s:
# Loss = 0.13028401692708333, Accuracy = 0.9817500000000001
# Validation loss = 0.1697998046875, Validation accuracy = 0.9644
# Epoch 90, training time = 35.34287977218628 s:
# Loss = 0.13143040974934897, Accuracy = 0.9813333333333335
# Validation loss = 0.18505859375, Validation accuracy = 0.9616
# Epoch 91, training time = 35.49214220046997 s:
# Loss = 0.13023300170898439, Accuracy = 0.9814166666666667
# Validation loss = 0.1822509765625, Validation accuracy = 0.9584
# Epoch 92, training time = 34.71218419075012 s:
# Loss = 0.13048675537109375, Accuracy = 0.9818166666666669
# Validation loss = 0.16552734375, Validation accuracy = 0.9664
# Epoch 93, training time = 34.27569365501404 s:
# Loss = 0.1287779744466146, Accuracy = 0.9824
# Validation loss = 0.1630859375, Validation accuracy = 0.9656
# Epoch 94, training time = 34.325557231903076 s:
# Loss = 0.12968994140625, Accuracy = 0.9820333333333334
# Validation loss = 0.1669921875, Validation accuracy = 0.9634
# Epoch 95, training time = 34.72868490219116 s:
# Loss = 0.12991785685221355, Accuracy = 0.9822166666666665
# Validation loss = 0.1632080078125, Validation accuracy = 0.9634
# Epoch 96, training time = 34.85778188705444 s:
# Loss = 0.1303901163736979, Accuracy = 0.9814666666666668
# Validation loss = 0.171630859375, Validation accuracy = 0.9616
# Epoch 97, training time = 35.21334958076477 s:
# Loss = 0.13003402709960937, Accuracy = 0.9820833333333333
# Validation loss = 0.166748046875, Validation accuracy = 0.9646
# Epoch 98, training time = 37.22873640060425 s:
# Loss = 0.13100677490234375, Accuracy = 0.9816833333333334
# Validation loss = 0.16259765625, Validation accuracy = 0.9636
# Epoch 99, training time = 37.20863962173462 s:
# Loss = 0.13170064290364583, Accuracy = 0.9806
# Validation loss = 0.155029296875, Validation accuracy = 0.9682

# %% [markdown]
# ### XNor Models

# %%
#del sys.modules["core.binary_models.layers"]
from core.numpy_models.full_precision_models.layers import Flatten, Softmax
from core.losses import CrossEntropy
from core.optimizers import GradientDescent, Adam
from core.label_utils import label_binerizer

from core.numpy_models.xnor_models.layers import XNorDense, XNorConv2D, BatchNorm
from core.numpy_models.binary_models.activation_layers import BinaryActivation
from core.model import Sequential

# %%
### Single conv + flatten + dense layer


model_layers = [
    Flatten(), 
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(10, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    Softmax()
]

loss_op = CrossEntropy()
optimizer_op = GradientDescent(lr=LR_SGD)

LeNet5_numpy = Sequential(model_layers)
LeNet5_numpy.compile(loss_op, optimizer_op)

for epoch in range(100):
    loss_batch = np.array([])
    acc_batch = np.array([])
    start_time = time.time()
    for j in range(len(X_train)//BATCH_SIZE):
        print(f"Batch {j}", end="\r")
        X_batch = X_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        y_batch = y_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        LeNet5_numpy.fit_step(X_batch, y_batch, curr_step=epoch)
        loss_batch = np.append(loss_batch, LeNet5_numpy.loss)
        acc_batch = np.append(acc_batch, LeNet5_numpy.accuracy)
    end_time = time.time()
    LeNet5_numpy.validate_step(X=X_test[:2000], y=y_test[:2000], curr_step=epoch)
    print(f"Epoch {epoch}, training time = {end_time-start_time} s:") 
    print(f"Loss = {np.mean(loss_batch)}, Accuracy = {np.mean(acc_batch)}")
    print(f"Validation loss = {LeNet5_numpy.validation_loss}, Validation accuracy = {LeNet5_numpy.validation_accuracy}")
# Out:
# Epoch 0: Loss = 0.6165789794921875, Accuracy = 0.8359333333333332
# Validation loss = 0.45361328125, Validation accuracy = 0.8775
# Epoch 1: Loss = 0.3451017761230469, Accuracy = 0.9127666666666666
# Validation loss = 0.37353515625, Validation accuracy = 0.9
# Epoch 2: Loss = 0.3038633728027344, Accuracy = 0.9246833333333332
# Validation loss = 0.345703125, Validation accuracy = 0.9105
# Epoch 3: Loss = 0.27795491536458333, Accuracy = 0.9336166666666667
# Validation loss = 0.32080078125, Validation accuracy = 0.912
# Epoch 4: Loss = 0.263067372639974, Accuracy = 0.9383333333333334
# Validation loss = 0.307373046875, Validation accuracy = 0.915
# Epoch 5: Loss = 0.24993306477864582, Accuracy = 0.9428833333333334
# Validation loss = 0.288330078125, Validation accuracy = 0.921
# Epoch 6: Loss = 0.24060007731119792, Accuracy = 0.9454333333333333
# Validation loss = 0.271240234375, Validation accuracy = 0.9285
# Epoch 7: Loss = 0.23425633748372396, Accuracy = 0.9477999999999999
# Validation loss = 0.271484375, Validation accuracy = 0.932
# Epoch 8: Loss = 0.22901585896809895, Accuracy = 0.94955
# Validation loss = 0.282958984375, Validation accuracy = 0.927
# Epoch 9: Loss = 0.22533910115559896, Accuracy = 0.9510499999999998
# Validation loss = 0.27392578125, Validation accuracy = 0.932
# Epoch 10: Loss = 0.2206664021809896, Accuracy = 0.9520000000000001
# Validation loss = 0.271484375, Validation accuracy = 0.931
# Epoch 11: Loss = 0.21627848307291667, Accuracy = 0.9537833333333333
# Validation loss = 0.25732421875, Validation accuracy = 0.936
# Epoch 12: Loss = 0.21391866048177083, Accuracy = 0.9537333333333333
# Validation loss = 0.25244140625, Validation accuracy = 0.9385
# Epoch 13: Loss = 0.2109166971842448, Accuracy = 0.9556166666666667
# Validation loss = 0.250732421875, Validation accuracy = 0.9375
# Epoch 14: Loss = 0.2101567586263021, Accuracy = 0.9557833333333334
# Validation loss = 0.2347412109375, Validation accuracy = 0.9435
# Epoch 15: Loss = 0.20896148681640625, Accuracy = 0.9569333333333333
# Validation loss = 0.239013671875, Validation accuracy = 0.9405
# Epoch 16: Loss = 0.20510747273763022, Accuracy = 0.9575666666666666
# Validation loss = 0.2474365234375, Validation accuracy = 0.9375
# Epoch 17: Loss = 0.2034162394205729, Accuracy = 0.9582166666666668
# Validation loss = 0.250732421875, Validation accuracy = 0.939
# Epoch 18: Loss = 0.20144210815429686, Accuracy = 0.9585833333333333
# Validation loss = 0.2471923828125, Validation accuracy = 0.94
# Epoch 19: Loss = 0.20302714029947916, Accuracy = 0.958
# Validation loss = 0.228759765625, Validation accuracy = 0.95
# Epoch 20: Loss = 0.2005963643391927, Accuracy = 0.9592666666666666
# Validation loss = 0.2314453125, Validation accuracy = 0.941
# Epoch 21: Loss = 0.19916524251302084, Accuracy = 0.9596999999999999
# Validation loss = 0.2413330078125, Validation accuracy = 0.94
# Epoch 22: Loss = 0.1977942403157552, Accuracy = 0.9599333333333334
# Validation loss = 0.2442626953125, Validation accuracy = 0.9395
# Epoch 23: Loss = 0.19654149373372395, Accuracy = 0.9606
# Validation loss = 0.2491455078125, Validation accuracy = 0.9315
# Epoch 24: Loss = 0.19836064656575522, Accuracy = 0.9597999999999998
# Validation loss = 0.2283935546875, Validation accuracy = 0.9425
# Epoch 25: Loss = 0.19478174845377605, Accuracy = 0.9609166666666666
# Validation loss = 0.246826171875, Validation accuracy = 0.94
# Epoch 26: Loss = 0.19518035888671875, Accuracy = 0.9604
# Validation loss = 0.2313232421875, Validation accuracy = 0.9465
# Epoch 27: Loss = 0.19464024861653645, Accuracy = 0.9607500000000001
# Validation loss = 0.2288818359375, Validation accuracy = 0.9435
# Epoch 28: Loss = 0.19176564534505208, Accuracy = 0.9618666666666666
# Validation loss = 0.2218017578125, Validation accuracy = 0.944
# Epoch 29: Loss = 0.19117879231770835, Accuracy = 0.9623833333333335
# Validation loss = 0.219482421875, Validation accuracy = 0.9475
# Epoch 30: Loss = 0.18998713175455728, Accuracy = 0.9626166666666666
# Validation loss = 0.226318359375, Validation accuracy = 0.947
# Epoch 31: Loss = 0.18943328857421876, Accuracy = 0.9623
# Validation loss = 0.2327880859375, Validation accuracy = 0.94
# Epoch 32: Loss = 0.188876953125, Accuracy = 0.9625
# Validation loss = 0.233642578125, Validation accuracy = 0.9435
# Epoch 33: Loss = 0.18949803670247395, Accuracy = 0.9620833333333333
# Validation loss = 0.236328125, Validation accuracy = 0.942
# Epoch 34: Loss = 0.18866444905598959, Accuracy = 0.9633166666666667
# Validation loss = 0.2294921875, Validation accuracy = 0.94
# Epoch 35: Loss = 0.18707860310872396, Accuracy = 0.963
# Validation loss = 0.2396240234375, Validation accuracy = 0.942
# Epoch 36: Loss = 0.1868188985188802, Accuracy = 0.9632333333333334
# Validation loss = 0.218505859375, Validation accuracy = 0.947
# Epoch 37: Loss = 0.186929931640625, Accuracy = 0.9634499999999999
# Validation loss = 0.23046875, Validation accuracy = 0.945
# Epoch 38: Loss = 0.1866235860188802, Accuracy = 0.9638333333333332
# Validation loss = 0.22509765625, Validation accuracy = 0.945
# Epoch 39: Loss = 0.18486251831054687, Accuracy = 0.9637166666666667
# Validation loss = 0.232177734375, Validation accuracy = 0.9415
# Epoch 40: Loss = 0.18477589925130208, Accuracy = 0.9640833333333332
# Validation loss = 0.214111328125, Validation accuracy = 0.951
# Epoch 41: Loss = 0.18556844075520834, Accuracy = 0.9635666666666667
# Validation loss = 0.2205810546875, Validation accuracy = 0.9485
# Epoch 42: Loss = 0.18320632934570313, Accuracy = 0.9649000000000001
# Validation loss = 0.217529296875, Validation accuracy = 0.9515
# Epoch 43: Loss = 0.18335098266601563, Accuracy = 0.9651666666666667
# Validation loss = 0.2305908203125, Validation accuracy = 0.944
# Epoch 44: Loss = 0.18248748779296875, Accuracy = 0.9652000000000001
# Validation loss = 0.2274169921875, Validation accuracy = 0.945
# Epoch 45: Loss = 0.1840119425455729, Accuracy = 0.9643833333333334
# Validation loss = 0.21875, Validation accuracy = 0.947
# Epoch 46: Loss = 0.18458226521809895, Accuracy = 0.9641833333333333
# Validation loss = 0.210693359375, Validation accuracy = 0.952
# Epoch 47: Loss = 0.18324488321940105, Accuracy = 0.9642833333333333
# Validation loss = 0.22314453125, Validation accuracy = 0.947
# Epoch 48: Loss = 0.18195933024088543, Accuracy = 0.9646833333333332
# Validation loss = 0.2237548828125, Validation accuracy = 0.946
# Epoch 49: Loss = 0.18016459147135416, Accuracy = 0.9661833333333334
# Validation loss = 0.2237548828125, Validation accuracy = 0.9485
# Epoch 50: Loss = 0.18156194051106772, Accuracy = 0.9656333333333331
# Validation loss = 0.225830078125, Validation accuracy = 0.9465
# Epoch 51: Loss = 0.1808228556315104, Accuracy = 0.9649833333333333
# Validation loss = 0.2274169921875, Validation accuracy = 0.944
# Epoch 52: Loss = 0.1800299072265625, Accuracy = 0.9656833333333332
# Validation loss = 0.2257080078125, Validation accuracy = 0.9445
# Epoch 53: Loss = 0.18129002888997395, Accuracy = 0.9659833333333334
# Validation loss = 0.2239990234375, Validation accuracy = 0.9465
# Epoch 54: Loss = 0.1792626953125, Accuracy = 0.9658166666666667
# Validation loss = 0.2125244140625, Validation accuracy = 0.9465
# Epoch 55: Loss = 0.17923487345377603, Accuracy = 0.9663666666666667
# Validation loss = 0.2147216796875, Validation accuracy = 0.9475
# Epoch 56: Loss = 0.17737177530924478, Accuracy = 0.9663333333333333
# Validation loss = 0.2186279296875, Validation accuracy = 0.951
# Epoch 57: Loss = 0.17875111897786458, Accuracy = 0.9658833333333333
# Validation loss = 0.21142578125, Validation accuracy = 0.95
# Epoch 58: Loss = 0.17824350992838542, Accuracy = 0.9657833333333333
# Validation loss = 0.213623046875, Validation accuracy = 0.9495
# Epoch 59: Loss = 0.17780293782552084, Accuracy = 0.9667
# Validation loss = 0.2158203125, Validation accuracy = 0.951
# Epoch 60: Loss = 0.17760386149088542, Accuracy = 0.9665333333333335
# Validation loss = 0.2161865234375, Validation accuracy = 0.946
# Epoch 61: Loss = 0.17701182047526043, Accuracy = 0.9669
# Validation loss = 0.2235107421875, Validation accuracy = 0.945
# Epoch 62: Loss = 0.17708765665690104, Accuracy = 0.9672666666666665
# Validation loss = 0.227783203125, Validation accuracy = 0.9455
# Epoch 63: Loss = 0.17750879923502605, Accuracy = 0.9668333333333332
# Validation loss = 0.2249755859375, Validation accuracy = 0.949
# Epoch 64: Loss = 0.17781590779622397, Accuracy = 0.9667833333333332
# Validation loss = 0.232666015625, Validation accuracy = 0.9435
# Epoch 65: Loss = 0.1752697245279948, Accuracy = 0.9674333333333334
# Validation loss = 0.2242431640625, Validation accuracy = 0.9475
# Epoch 66: Loss = 0.17621729532877603, Accuracy = 0.9675666666666666
# Validation loss = 0.2265625, Validation accuracy = 0.945
# Epoch 67: Loss = 0.17697057088216145, Accuracy = 0.9665833333333332
# Validation loss = 0.21826171875, Validation accuracy = 0.947
# Epoch 68: Loss = 0.17656600952148438, Accuracy = 0.9670666666666666
# Validation loss = 0.2161865234375, Validation accuracy = 0.9495
# Epoch 69: Loss = 0.17581929524739584, Accuracy = 0.9669333333333334
# Validation loss = 0.2257080078125, Validation accuracy = 0.946
# Epoch 70: Loss = 0.1765485127766927, Accuracy = 0.9665333333333332
# Validation loss = 0.2158203125, Validation accuracy = 0.951
# Epoch 71: Loss = 0.1771350606282552, Accuracy = 0.9670166666666667
# Validation loss = 0.2117919921875, Validation accuracy = 0.9485
# Epoch 72: Loss = 0.175999755859375, Accuracy = 0.9670666666666666
# Validation loss = 0.216552734375, Validation accuracy = 0.947
# Epoch 73: Loss = 0.17585591634114583, Accuracy = 0.9681166666666666
# Validation loss = 0.2149658203125, Validation accuracy = 0.943
# Epoch 74: Loss = 0.17447596232096355, Accuracy = 0.9678666666666668
# Validation loss = 0.21728515625, Validation accuracy = 0.9475
# Epoch 75: Loss = 0.1750829060872396, Accuracy = 0.9675666666666666
# Validation loss = 0.22265625, Validation accuracy = 0.9475
# Epoch 76: Loss = 0.17604451497395834, Accuracy = 0.9674166666666667
# Validation loss = 0.220947265625, Validation accuracy = 0.947
# Epoch 77: Loss = 0.1766717529296875, Accuracy = 0.9675666666666666
# Validation loss = 0.2159423828125, Validation accuracy = 0.9505
# Epoch 78: Loss = 0.1770555623372396, Accuracy = 0.9669333333333334
# Validation loss = 0.2266845703125, Validation accuracy = 0.95
# Epoch 79: Loss = 0.17579610188802083, Accuracy = 0.9669000000000002
# Validation loss = 0.2196044921875, Validation accuracy = 0.9475
# Epoch 80: Loss = 0.17619008382161458, Accuracy = 0.9674833333333334
# Validation loss = 0.22802734375, Validation accuracy = 0.9465
# Epoch 81: Loss = 0.17571980794270833, Accuracy = 0.9673333333333332
# Validation loss = 0.207763671875, Validation accuracy = 0.953
# Epoch 82: Loss = 0.1758246866861979, Accuracy = 0.9672833333333334
# Validation loss = 0.227294921875, Validation accuracy = 0.942
# Epoch 83: Loss = 0.1748078918457031, Accuracy = 0.9671333333333335
# Validation loss = 0.2357177734375, Validation accuracy = 0.9395
# Epoch 84: Loss = 0.17722671508789062, Accuracy = 0.9665666666666666
# Validation loss = 0.2166748046875, Validation accuracy = 0.949
# Epoch 85: Loss = 0.1750501505533854, Accuracy = 0.9675333333333334
# Validation loss = 0.2147216796875, Validation accuracy = 0.95
# Epoch 86: Loss = 0.17544326782226563, Accuracy = 0.9670833333333333
# Validation loss = 0.22900390625, Validation accuracy = 0.943
# Epoch 87: Loss = 0.17549697875976564, Accuracy = 0.9677666666666667
# Validation loss = 0.229736328125, Validation accuracy = 0.942
# Epoch 88: Loss = 0.17599049886067708, Accuracy = 0.9677333333333333
# Validation loss = 0.22314453125, Validation accuracy = 0.944
# Epoch 89: Loss = 0.17459996541341147, Accuracy = 0.9678166666666668
# Validation loss = 0.2159423828125, Validation accuracy = 0.949
# Epoch 90: Loss = 0.1742505391438802, Accuracy = 0.9680666666666665
# Validation loss = 0.2293701171875, Validation accuracy = 0.946
# Epoch 91: Loss = 0.17324289957682293, Accuracy = 0.96745
# Validation loss = 0.22216796875, Validation accuracy = 0.9455
# Epoch 92: Loss = 0.1746569315592448, Accuracy = 0.9677666666666668
# Validation loss = 0.2249755859375, Validation accuracy = 0.948
# Epoch 93: Loss = 0.17505839029947917, Accuracy = 0.9671
# Validation loss = 0.2137451171875, Validation accuracy = 0.949
# Epoch 94: Loss = 0.17609349568684896, Accuracy = 0.9668166666666668
# Validation loss = 0.222900390625, Validation accuracy = 0.9455
# Epoch 95: Loss = 0.174095458984375, Accuracy = 0.9678500000000001
# Validation loss = 0.2166748046875, Validation accuracy = 0.9465
# Epoch 96: Loss = 0.1735039265950521, Accuracy = 0.9686499999999999
# Validation loss = 0.2222900390625, Validation accuracy = 0.945
# Epoch 97: Loss = 0.17420277913411458, Accuracy = 0.9673833333333333
# Validation loss = 0.2210693359375, Validation accuracy = 0.9445
# Epoch 98: Loss = 0.17364395141601563, Accuracy = 0.9675666666666666
# Validation loss = 0.2149658203125, Validation accuracy = 0.948
# Epoch 99: Loss = 0.17460993448893228, Accuracy = 0.9671166666666666
# Validation loss = 0.21728515625, Validation accuracy = 0.9475

# %%
### Single conv + flatten + dense layer


model_layers = [
    Flatten(), 
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(256, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    BinaryActivation(dtype=DTYPE),
    XNorDense(10, dtype=DTYPE),
    BatchNorm(BATCH_NORM_MOMENTUM),
    Softmax()
]

loss_op = CrossEntropy()
optimizer_op = Adam(lr=LR_ADAM)

LeNet5_numpy = Sequential(model_layers)
LeNet5_numpy.compile(loss_op, optimizer_op)

for epoch in range(100):
    loss_batch = np.array([])
    acc_batch = np.array([])
    start_time = time.time()
    for j in range(len(X_train)//BATCH_SIZE):
        print(f"Batch {j}", end="\r")
        X_batch = X_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        y_batch = y_train[j*BATCH_SIZE:(j+1)*BATCH_SIZE]
        LeNet5_numpy.fit_step(X_batch, y_batch, curr_step=epoch)
        loss_batch = np.append(loss_batch, LeNet5_numpy.loss)
        acc_batch = np.append(acc_batch, LeNet5_numpy.accuracy)
    end_time = time.time()
    LeNet5_numpy.validate_step(X=X_test[:2000], y=y_test[:2000], curr_step=epoch)
    print(f"Epoch {epoch}, training time = {end_time-start_time} s:") 
    print(f"Loss = {np.mean(loss_batch)}, Accuracy = {np.mean(acc_batch)}")
    print(f"Validation loss = {LeNet5_numpy.validation_loss}, Validation accuracy = {LeNet5_numpy.validation_accuracy}")
# Out:
# Epoch 0: Loss = 0.42358184814453126, Accuracy = 0.8899333333333334
# Validation loss = 0.359375, Validation accuracy = 0.9045
# Epoch 1: Loss = 0.29525146484375, Accuracy = 0.9285333333333333
# Validation loss = 0.321533203125, Validation accuracy = 0.9225
# Epoch 2: Loss = 0.26822703043619794, Accuracy = 0.9368166666666667
# Validation loss = 0.296630859375, Validation accuracy = 0.9265
# Epoch 3: Loss = 0.2532208760579427, Accuracy = 0.9410333333333334
# Validation loss = 0.28564453125, Validation accuracy = 0.9275
# Epoch 4: Loss = 0.24454208374023437, Accuracy = 0.9443999999999998
# Validation loss = 0.267333984375, Validation accuracy = 0.93
# Epoch 5: Loss = 0.23999287923177084, Accuracy = 0.9449833333333334
# Validation loss = 0.261474609375, Validation accuracy = 0.934
# Epoch 6: Loss = 0.23208094278971353, Accuracy = 0.9489833333333333
# Validation loss = 0.269287109375, Validation accuracy = 0.931
# Epoch 7: Loss = 0.23028477986653645, Accuracy = 0.9480499999999998
# Validation loss = 0.26220703125, Validation accuracy = 0.934
# Epoch 8: Loss = 0.22565109252929688, Accuracy = 0.9501833333333332
# Validation loss = 0.26123046875, Validation accuracy = 0.929
# Epoch 9: Loss = 0.22236658732096354, Accuracy = 0.9514666666666667
# Validation loss = 0.25830078125, Validation accuracy = 0.9315
# Epoch 10: Loss = 0.2222265625, Accuracy = 0.9508333333333333
# Validation loss = 0.2646484375, Validation accuracy = 0.932
# Epoch 11: Loss = 0.21984965006510418, Accuracy = 0.95295
# Validation loss = 0.2568359375, Validation accuracy = 0.932
# Epoch 12: Loss = 0.2199860636393229, Accuracy = 0.9519666666666667
# Validation loss = 0.25244140625, Validation accuracy = 0.9355
# Epoch 13: Loss = 0.21741226196289062, Accuracy = 0.9523166666666668
# Validation loss = 0.2470703125, Validation accuracy = 0.939
# Epoch 14: Loss = 0.21603322347005208, Accuracy = 0.9536499999999999
# Validation loss = 0.2481689453125, Validation accuracy = 0.9375
# Epoch 15: Loss = 0.21399195353190104, Accuracy = 0.9542833333333333
# Validation loss = 0.2430419921875, Validation accuracy = 0.9425
# Epoch 16: Loss = 0.21303441365559897, Accuracy = 0.9546166666666667
# Validation loss = 0.243896484375, Validation accuracy = 0.939
# Epoch 17: Loss = 0.21000015258789062, Accuracy = 0.9553000000000001
# Validation loss = 0.238525390625, Validation accuracy = 0.942
# Epoch 18: Loss = 0.20941248575846355, Accuracy = 0.9554833333333332
# Validation loss = 0.24658203125, Validation accuracy = 0.9365
# Epoch 19: Loss = 0.2066822814941406, Accuracy = 0.9565833333333335
# Validation loss = 0.245361328125, Validation accuracy = 0.938
# Epoch 20: Loss = 0.2064515177408854, Accuracy = 0.9571166666666666
# Validation loss = 0.245361328125, Validation accuracy = 0.935
# Epoch 21: Loss = 0.2063941446940104, Accuracy = 0.95625
# Validation loss = 0.23974609375, Validation accuracy = 0.94
# Epoch 22: Loss = 0.20553848266601563, Accuracy = 0.9577
# Validation loss = 0.239013671875, Validation accuracy = 0.9375
# Epoch 23: Loss = 0.20447301228841147, Accuracy = 0.9577500000000001
# Validation loss = 0.2386474609375, Validation accuracy = 0.94
# Epoch 24: Loss = 0.20420440673828125, Accuracy = 0.9578833333333333
# Validation loss = 0.2322998046875, Validation accuracy = 0.9435
# Epoch 25: Loss = 0.20236399332682292, Accuracy = 0.9583666666666666
# Validation loss = 0.2349853515625, Validation accuracy = 0.9385
# Epoch 26: Loss = 0.20315292358398437, Accuracy = 0.9570499999999998
# Validation loss = 0.2362060546875, Validation accuracy = 0.9395
# Epoch 27: Loss = 0.20385009765625, Accuracy = 0.9579
# Validation loss = 0.2318115234375, Validation accuracy = 0.945
# Epoch 28: Loss = 0.20156941731770833, Accuracy = 0.9585
# Validation loss = 0.2437744140625, Validation accuracy = 0.941
# Epoch 29: Loss = 0.200130615234375, Accuracy = 0.9589499999999999
# Validation loss = 0.23291015625, Validation accuracy = 0.9405
# Epoch 30: Loss = 0.2007245381673177, Accuracy = 0.9589333333333332
# Validation loss = 0.248779296875, Validation accuracy = 0.937
# Epoch 31: Loss = 0.1970838419596354, Accuracy = 0.9599833333333333
# Validation loss = 0.241455078125, Validation accuracy = 0.937
# Epoch 32: Loss = 0.20019368489583333, Accuracy = 0.9588166666666667
# Validation loss = 0.243896484375, Validation accuracy = 0.941
# Epoch 33: Loss = 0.19843948364257813, Accuracy = 0.95985
# Validation loss = 0.2430419921875, Validation accuracy = 0.941
# Epoch 34: Loss = 0.1977507019042969, Accuracy = 0.96005
# Validation loss = 0.2303466796875, Validation accuracy = 0.946
# Epoch 35: Loss = 0.196964111328125, Accuracy = 0.9601499999999998
# Validation loss = 0.244140625, Validation accuracy = 0.944
# Epoch 36: Loss = 0.1964404296875, Accuracy = 0.9603166666666667
# Validation loss = 0.2327880859375, Validation accuracy = 0.943
# Epoch 37: Loss = 0.1950926717122396, Accuracy = 0.9603333333333333
# Validation loss = 0.229248046875, Validation accuracy = 0.949
# Epoch 38: Loss = 0.19355738321940105, Accuracy = 0.9612833333333333
# Validation loss = 0.24560546875, Validation accuracy = 0.9365
# Epoch 39: Loss = 0.19427871704101562, Accuracy = 0.9605499999999999
# Validation loss = 0.225341796875, Validation accuracy = 0.9415
# Epoch 40: Loss = 0.1947357177734375, Accuracy = 0.9610000000000001
# Validation loss = 0.23974609375, Validation accuracy = 0.942
# Epoch 41: Loss = 0.1940777587890625, Accuracy = 0.9617333333333332
# Validation loss = 0.2315673828125, Validation accuracy = 0.944
# Epoch 42: Loss = 0.19311665852864585, Accuracy = 0.9613166666666666
# Validation loss = 0.2366943359375, Validation accuracy = 0.941
# Epoch 43: Loss = 0.1930621337890625, Accuracy = 0.9618499999999999
# Validation loss = 0.222412109375, Validation accuracy = 0.9475
# Epoch 44: Loss = 0.19125193277994793, Accuracy = 0.9625499999999999
# Validation loss = 0.236572265625, Validation accuracy = 0.943
# Epoch 45: Loss = 0.19288553873697917, Accuracy = 0.9617499999999999
# Validation loss = 0.245361328125, Validation accuracy = 0.9415
# Epoch 46: Loss = 0.19210362752278645, Accuracy = 0.9620833333333333
# Validation loss = 0.2330322265625, Validation accuracy = 0.946
# Epoch 47: Loss = 0.19196085611979166, Accuracy = 0.9618666666666666
# Validation loss = 0.235107421875, Validation accuracy = 0.943
# Epoch 48: Loss = 0.19141983032226562, Accuracy = 0.9625333333333334
# Validation loss = 0.2236328125, Validation accuracy = 0.9475
# Epoch 49: Loss = 0.1924572245279948, Accuracy = 0.9617
# Validation loss = 0.22265625, Validation accuracy = 0.952
# Epoch 50: Loss = 0.1903380330403646, Accuracy = 0.9625666666666666
# Validation loss = 0.2471923828125, Validation accuracy = 0.944
# Epoch 51: Loss = 0.1918377685546875, Accuracy = 0.9626166666666666
# Validation loss = 0.2259521484375, Validation accuracy = 0.9455
# Epoch 52: Loss = 0.1901183064778646, Accuracy = 0.9630666666666665
# Validation loss = 0.23193359375, Validation accuracy = 0.947
# Epoch 53: Loss = 0.1902306620279948, Accuracy = 0.9622499999999998
# Validation loss = 0.2305908203125, Validation accuracy = 0.943
# Epoch 54: Loss = 0.18963816324869792, Accuracy = 0.9628666666666665
# Validation loss = 0.2391357421875, Validation accuracy = 0.94
# Epoch 55: Loss = 0.18763748168945313, Accuracy = 0.9637333333333333
# Validation loss = 0.2252197265625, Validation accuracy = 0.95
# Epoch 56: Loss = 0.18869766235351562, Accuracy = 0.9636999999999999
# Validation loss = 0.227294921875, Validation accuracy = 0.9455
# Epoch 57: Loss = 0.1891132100423177, Accuracy = 0.9632666666666665
# Validation loss = 0.22900390625, Validation accuracy = 0.946
# Epoch 58: Loss = 0.18772908528645835, Accuracy = 0.9635666666666667
# Validation loss = 0.214111328125, Validation accuracy = 0.9505
# Epoch 59: Loss = 0.1888031514485677, Accuracy = 0.9627999999999999
# Validation loss = 0.2242431640625, Validation accuracy = 0.9465
# Epoch 60: Loss = 0.18771657307942707, Accuracy = 0.9632
# Validation loss = 0.2286376953125, Validation accuracy = 0.9425
# Epoch 61: Loss = 0.18712066650390624, Accuracy = 0.9631833333333335
# Validation loss = 0.2276611328125, Validation accuracy = 0.9495
# Epoch 62: Loss = 0.18837860107421875, Accuracy = 0.96335
# Validation loss = 0.2291259765625, Validation accuracy = 0.9445
# Epoch 63: Loss = 0.18764572143554686, Accuracy = 0.9627333333333333
# Validation loss = 0.2291259765625, Validation accuracy = 0.944
# Epoch 64: Loss = 0.1868169148763021, Accuracy = 0.9637333333333333
# Validation loss = 0.2276611328125, Validation accuracy = 0.9425
# Epoch 65: Loss = 0.18758941650390626, Accuracy = 0.96295
# Validation loss = 0.224365234375, Validation accuracy = 0.9485
# Epoch 66: Loss = 0.18718582153320312, Accuracy = 0.9634833333333334
# Validation loss = 0.2177734375, Validation accuracy = 0.948
# Epoch 67: Loss = 0.18789077758789063, Accuracy = 0.9634833333333332
# Validation loss = 0.223388671875, Validation accuracy = 0.945
# Epoch 68: Loss = 0.18757766723632813, Accuracy = 0.9633833333333333
# Validation loss = 0.2119140625, Validation accuracy = 0.948
# Epoch 69: Loss = 0.18877644856770834, Accuracy = 0.9628333333333332
# Validation loss = 0.2177734375, Validation accuracy = 0.9465
# Epoch 70: Loss = 0.18746480305989582, Accuracy = 0.9633333333333334
# Validation loss = 0.233642578125, Validation accuracy = 0.949
# Epoch 71: Loss = 0.18538162231445313, Accuracy = 0.96375
# Validation loss = 0.2265625, Validation accuracy = 0.945
# Epoch 72: Loss = 0.18605489095052083, Accuracy = 0.9637666666666667
# Validation loss = 0.231201171875, Validation accuracy = 0.9425
# Epoch 73: Loss = 0.1864989725748698, Accuracy = 0.96295
# Validation loss = 0.2274169921875, Validation accuracy = 0.949
# Epoch 74: Loss = 0.18725021362304686, Accuracy = 0.9634999999999998
# Validation loss = 0.22900390625, Validation accuracy = 0.945
# Epoch 75: Loss = 0.18692296346028645, Accuracy = 0.9635500000000001
# Validation loss = 0.2197265625, Validation accuracy = 0.9475
# Epoch 76: Loss = 0.18353958129882814, Accuracy = 0.9643666666666665
# Validation loss = 0.218505859375, Validation accuracy = 0.948
# Epoch 77: Loss = 0.18532389322916668, Accuracy = 0.9637333333333333
# Validation loss = 0.2191162109375, Validation accuracy = 0.9465
# Epoch 78: Loss = 0.18483444213867187, Accuracy = 0.9645833333333333
# Validation loss = 0.22021484375, Validation accuracy = 0.948
# Epoch 79: Loss = 0.1844902547200521, Accuracy = 0.9646833333333332
# Validation loss = 0.2113037109375, Validation accuracy = 0.947
# Epoch 80: Loss = 0.18435028076171875, Accuracy = 0.9647000000000001
# Validation loss = 0.22314453125, Validation accuracy = 0.947
# Epoch 81: Loss = 0.18332148234049478, Accuracy = 0.9650333333333333
# Validation loss = 0.220703125, Validation accuracy = 0.9455
# Epoch 82: Loss = 0.1839238993326823, Accuracy = 0.9649333333333334
# Validation loss = 0.220458984375, Validation accuracy = 0.9515
# Epoch 83: Loss = 0.1842475382486979, Accuracy = 0.9647000000000001
# Validation loss = 0.2174072265625, Validation accuracy = 0.948
# Epoch 84: Loss = 0.1848298136393229, Accuracy = 0.9643
# Validation loss = 0.2275390625, Validation accuracy = 0.947
# Epoch 85: Loss = 0.1832793680826823, Accuracy = 0.9652333333333333
# Validation loss = 0.23193359375, Validation accuracy = 0.947
# Epoch 86: Loss = 0.18555465698242188, Accuracy = 0.9642999999999998
# Validation loss = 0.2188720703125, Validation accuracy = 0.95
# Epoch 87: Loss = 0.1821989949544271, Accuracy = 0.9653499999999998
# Validation loss = 0.226318359375, Validation accuracy = 0.9475
# Epoch 88: Loss = 0.18302159627278647, Accuracy = 0.96535
# Validation loss = 0.2271728515625, Validation accuracy = 0.941
# Epoch 89: Loss = 0.1830840047200521, Accuracy = 0.9650666666666666
# Validation loss = 0.2244873046875, Validation accuracy = 0.9485
# Epoch 90: Loss = 0.18231801350911458, Accuracy = 0.9647666666666667
# Validation loss = 0.21826171875, Validation accuracy = 0.9485
# Epoch 91: Loss = 0.18156661987304687, Accuracy = 0.9652499999999999
# Validation loss = 0.2283935546875, Validation accuracy = 0.9475
# Epoch 92: Loss = 0.18146860758463543, Accuracy = 0.9654
# Validation loss = 0.2193603515625, Validation accuracy = 0.9475
# Epoch 93: Loss = 0.18265838623046876, Accuracy = 0.9650166666666666
# Validation loss = 0.222900390625, Validation accuracy = 0.948
# Epoch 94: Loss = 0.18224894205729167, Accuracy = 0.9646333333333333
# Validation loss = 0.22998046875, Validation accuracy = 0.945
# Epoch 95: Loss = 0.18146799723307291, Accuracy = 0.9657166666666668
# Validation loss = 0.21875, Validation accuracy = 0.946
# Epoch 96: Loss = 0.1818914286295573, Accuracy = 0.9655499999999999
# Validation loss = 0.2176513671875, Validation accuracy = 0.949
# Epoch 97: Loss = 0.18196385701497395, Accuracy = 0.9650666666666666
# Validation loss = 0.221923828125, Validation accuracy = 0.9475
# Epoch 98: Loss = 0.18203201293945312, Accuracy = 0.9654333333333334
# Validation loss = 0.22998046875, Validation accuracy = 0.9425
# Epoch 99: Loss = 0.18165934244791668, Accuracy = 0.9654999999999999
# Validation loss = 0.228759765625, Validation accuracy = 0.947
